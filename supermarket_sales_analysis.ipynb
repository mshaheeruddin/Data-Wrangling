# %% [markdown]
# Data Exploration

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv('supermarket_sales_dirty.csv')
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995          NaN      C  Naypyitaw        Normal    Male
# 996          NaN      B   Mandalay        Normal  Female
# 997          NaN      A     Yangon        Member    Male
# 998          NaN      A     Yangon        Normal    Male
# 999          NaN      A     Yangon        Member  Female
#
#                Product line  Unit price Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69        7  26.1415  548.9715
# 1    Electronic accessories       15.28        5   3.8200     80.22
# 2        Home and lifestyle       46.33        7  16.2155  340.5255
# ...

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data_subset =data[['Branch', 'City', 'Customer type', 'Gender',
       'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
       'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
       'Rating']]

# %% [markdown]
# Missing Values Check

# %%
data_subset.isna().sum()
# Out:
# Branch                     19
# City                        4
# Customer type               0
# Gender                      9
# Product line                5
# Unit price                  8
# Quantity                    4
# Tax 5%                      0
# Total                       3
# Date                        0
# Time                       35
# Payment                     9
# cogs                       11
# gross margin percentage     9
# gross income                0
# Rating                      6
# dtype: int64

# %% [markdown]
# Check across gross income column

# %%
data_subset[data_subset['gross income'].isna()]
# Out:
# Empty DataFrame
# Columns: [Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %% [markdown]
# Numerical values check

# %%
data_subset.describe()
# Out:
#        Unit price       Tax 5%        cogs      Rating
# count  992.000000  1000.000000  989.000000  994.000000
# mean    55.658306    15.379369  308.662103    6.968612
# std     26.561547    11.708825  234.098759    1.716175
# min     10.080000     0.508500   10.170000    4.000000
# 25%     32.687500     5.924875  119.720000    5.500000
# 50%     55.230000    12.088000  243.000000    6.950000
# 75%     77.980000    22.445250  449.820000    8.475000
# max     99.960000    49.650000  993.000000   10.000000

# %%
data_subset.dtypes
# Out:
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                    object
# Tax 5%                     float64
# Total                       object
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage     object
# gross income                object
# Rating                     float64
# dtype: object

# %%
data_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Unit price'}>,
#         <AxesSubplot:title={'center':'Tax 5%'}>],
#        [<AxesSubplot:title={'center':'cogs'}>,
#         <AxesSubplot:title={'center':'Rating'}>]], dtype=object)
